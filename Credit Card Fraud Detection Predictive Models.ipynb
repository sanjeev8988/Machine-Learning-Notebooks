# %%
import pandas as pd

# %%
data=pd.read_csv("creditcard.csv",header=0)

# %%
data.head()
# Out:
#    Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 0   0.0 -1.359807 -0.072781  2.536347  ...  0.133558 -0.021053  149.62      0
# 1   0.0  1.191857  0.266151  0.166480  ... -0.008983  0.014724    2.69      0
# 2   1.0 -1.358354 -1.340163  1.773209  ... -0.055353 -0.059752  378.66      0
# 3   1.0 -0.966272 -0.185226  1.792993  ...  0.062723  0.061458  123.50      0
# 4   2.0 -1.158233  0.877737  1.548718  ...  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
data.shape
# Out:
# (284807, 31)

# %%
data.shape[0]
# Out:
# 284807

# %%
data.shape[1]
# Out:
# 31

# %%
data.describe()
# Out:
#                 Time            V1  ...         Amount          Class
# count  284807.000000  2.848070e+05  ...  284807.000000  284807.000000
# mean    94813.859575  3.919560e-15  ...      88.349619       0.001727
# std     47488.145955  1.958696e+00  ...     250.120109       0.041527
# min         0.000000 -5.640751e+01  ...       0.000000       0.000000
# 25%     54201.500000 -9.203734e-01  ...       5.600000       0.000000
# 50%     84692.000000  1.810880e-02  ...      22.000000       0.000000
# 75%    139320.500000  1.315642e+00  ...      77.165000       0.000000
# max    172792.000000  2.454930e+00  ...   25691.160000       1.000000
#
# [8 rows x 31 columns]

# %% [markdown]
# Check Missing Data

# %%
total = data.isnull().sum().sort_values(ascending = False)

# %%
print(total)
# Out:
# Class     0
# V14       0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V15       0
# Amount    0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Time      0
# dtype: int64

# %%
cnt = data.isnull().count()

# %%
cnt
# Out:
# Time      284807
# V1        284807
# V2        284807
# V3        284807
# V4        284807
# V5        284807
# V6        284807
# V7        284807
# V8        284807
# V9        284807
# V10       284807
# V11       284807
# V12       284807
# V13       284807
# V14       284807
# V15       284807
# V16       284807
# V17       284807
# V18       284807
# V19       284807
# V20       284807
# V21       284807
# V22       284807
# V23       284807
# V24       284807
# V25       284807
# V26       284807
# V27       284807
# V28       284807
# Amount    284807
# Class     284807
# dtype: int64

# %% [markdown]
# check for Unbalance of data

# %%
temp= data['Class'].value_counts()

# %%
temp
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
type(temp)
# Out:
# pandas.core.series.Series

# %%
df = pd.DataFrame({'Class' : temp.index, 'values' : temp.values})

# %%
df.shape
# Out:
# (2, 2)

# %%
df
# Out:
#    Class  values
# 0      0  284315
# 1      1     492

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
# %matplotlib inline
import plotly.graph_objs as go
import plotly.figure_factory as ff
from plotly import tools
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import gc

# %%
init_notebook_mode(connected = True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
trace = go.Bar( 
    x = df['Class'], 
    y = df['values'], 
    name = "Credit card fraud data- Unbalanced (fraud: 1, not Fraud: 0)", 
    marker = dict(color = "Red"), 
    text = df['values']
    )

# %%
type(trace)
# Out:
# plotly.graph_objs.Bar

# %%
trace
# Out:
# Bar({
#     'marker': {'color': 'Red'},
#     'name': 'Credit card fraud data- Unbalanced (fraud: 1, not Fraud: 0)',
#     'text': array([284315.,    492.]),
#     'x': array([0, 1]),
#     'y': array([284315,    492])
# })

# %%
data_n = [trace]

# %%
type(data_n)
# Out:
# list

# %%
data_n
# Out:
# [Bar({
#      'marker': {'color': 'Red'},
#      'name': 'Credit card fraud data- Unbalanced (fraud: 1, not Fraud: 0)',
#      'text': array([284315.,    492.]),
#      'x': array([0, 1]),
#      'y': array([284315,    492])
#  })]

# %%
layout_n = dict(title = "Credit card fraud data- Unbalanced (fraud: 1, not Fraud: 0)",
                xaxis = dict(title ='Class', showticklabels = True),
                yaxis = dict(title = 'number of transections'),
                hovermode = 'closest',
                width = 600
                )

# %%
fig = dict(data = data_n, layout = layout_n)
iplot (fig, filename = 'Class')
# Out:
# <div>
#
#
#             <div id="0f1606b6-21b8-4184-8182-37b39851af8d" class="plotly-graph-div" style="height:525px; width:600px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0f1606b6-21b8-4184-8182-37b39851af8d")) {
#                     Plotly.newPlot(
#                         '0f1606b6-21b8-4184-8182-37b39851af8d',
#                         [{"marker": {"color": "Red"}, "name": "Credit card fraud data- Unbalanced (fraud: 1, not Fraud: 0)", "text": [284315.0, 492.0], "type": "bar", "x": [0, 1], "y": [284315, 492]}],
# ...

# %%
import plotly
plotly.version
# Out:
# <module 'plotly.version' from '/usr/local/lib/python3.7/dist-packages/plotly/version.py'>
